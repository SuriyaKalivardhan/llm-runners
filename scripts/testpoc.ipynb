# %%
from openai import OpenAI
from openai.types.chat import ChatCompletion
client = OpenAI()

# %%
response:ChatCompletion = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {
                    "role": "user",
                     "content": [
                       {"type": "text", "text": "How to say hello?"},
                        # {"type": "image_url", "image_url": {
                        #     #"url": "https://images.saymedia-content.com/.image/c_limit%2Ccs_srgb%2Cq_auto:eco%2Cw_538/MTczOTQ5NDQyMzQ3NTc0NTc5/compound-shapes-how-to-find-the-area-of-a-l-shape.webp"
                        #     #"url":"https://upload.wikimedia.org/wikipedia/commons/thumb/f/fc/Gabbiani%2C_Giovanni_Gaetano_%28attr.%29_-_Official_portrait_of_Cosimo_III_de%27_Medici_as_Grand_Duke_of_Tuscany.jpg/1200px-Gabbiani%2C_Giovanni_Gaetano_%28attr.%29_-_Official_portrait_of_Cosimo_III_de%27_Medici_as_Grand_Duke_of_Tuscany.jpg"
                        #     "url": "https://upload.wikimedia.org/wikipedia/en/8/8b/60_Summers_by_Graeme_Connors.png"
                        #     }
                        # }
                     ]
                },
            ],
            max_tokens=1000,
            stream=False,
        )

# %%
response.choices[0].message.content.splitlines()
# Out:
# ['The way to say "hello" can vary depending on the language and context. Here are a few examples from different languages:',
#  '',
#  '1. English: Hello',
#  '2. Spanish: Hola',
#  '3. French: Bonjour',
#  '4. German: Hallo',
#  '5. Italian: Ciao (informal) or Salve (formal)',
#  '6. Chinese (Mandarin): 你好 (Nǐ hǎo)',
#  '7. Japanese: こんにちは (Konnichiwa)',
#  '8. Korean: 안녕하세요 (Annyeong-haseyo)',
#  '9. Arabic: مرحبا (Marhabaan)',
#  '10. Russian: Здравствуйте (Zdravstvuyte)',
#  '',
#  'Feel free to ask for specific languages or contexts if you need more information!']

# %%
import requests
import wikipediaapi
from wikipediaapi import Wikipedia

#r_resp = requests.get("https://commons.wikimedia.org/wiki/Special:Random/File")
r_resp = requests.get("https://en.wikipedia.org/wiki/60_Summers")
r_resp.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-appearance-disabled vector-feature-appearance-pinned-clientpref-0 vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>60 Summers - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-fea
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(r_resp.text, 'html.parser')

# %%
images = soup.find_all("meta", {"property": "og:image"})
images[-1]['content']
# Out:
# 'https://upload.wikimedia.org/wikipedia/en/8/8b/60_Summers_by_Graeme_Connors.png'

# %%
title = soup.find("title")
title.string.removesuffix(" - Wikipedia")
# Out:
# '60 Summers'
